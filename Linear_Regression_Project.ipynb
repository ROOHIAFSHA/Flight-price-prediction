# %%
# Linear Regression Project#1 - Flight booking data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\nnallabo

# %%
os.chdir("C:\\Users\\nnallabo\\OneDrive - Qualcomm\\Documents\\Python-DS\\Linear Regression")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nnallabo\\OneDrive - Qualcomm\\Documents\\Python-DS\\Linear Regression'

# %%
data = pd.read_csv("LR_Dataset.csv")

# %%
data.shape
# Out:
# (300153, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
data.describe()
# Out:
#           Unnamed: 0       duration      days_left          price
# count  300153.000000  300153.000000  300153.000000  300153.000000
# mean   150076.000000      12.221021      26.004751   20889.660523
# std     86646.852011       7.191997      13.561004   22697.767366
# min         0.000000       0.830000       1.000000    1105.000000
# 25%     75038.000000       6.830000      15.000000    4783.000000
# 50%    150076.000000      11.250000      26.000000    7425.000000
# 75%    225114.000000      16.170000      38.000000   42521.000000
# max    300152.000000      49.830000      49.000000  123071.000000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.count()
# Out:
# Unnamed: 0          300153
# airline             300153
# flight              300153
# source_city         300153
# departure_time      300153
# stops               300153
# arrival_time        300153
# destination_city    300153
# class               300153
# duration            300153
# days_left           300153
# price               300153
# dtype: int64

# %%
data["airline"].unique()
# Out:
# array(['SpiceJet', 'AirAsia', 'Vistara', 'GO_FIRST', 'Indigo',
#        'Air_India'], dtype=object)

# %%
sns.catplot(y = "price", x = "airline", data = data.sort_values("price", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()
# price vary with airlines, Vistara has high price and Air Asia has low.

# %%
#Scatter plot
plt.title("Price vs airline")
plt.xlabel("airline")
plt.ylabel("Price")
sns.scatterplot(x='airline', y='price', data=data)
# Out:
# <AxesSubplot:title={'center':'Price vs airline'}, xlabel='airline', ylabel='Price'>

# %%
plt.figure(figsize = (15,4))
plt.title('price VS days_left')
plt.scatter(data['days_left'], data['price'])
plt.xlabel('days_left')
plt.ylabel('price')
plt.xticks(rotation = 90)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
sns.catplot(y = "price", x = "days_left", data = data.sort_values("price", ascending = False), kind="boxen", height = 4, aspect = 3)
plt.show()
#price is not affected much when tickets are bought in just 1 or 2 days before departure

# %%
# Plotting Bar chart for Months (Duration) vs Number of Flights
plt.figure(figsize = (10, 5))
plt.title('Price vs days_left')
ax=sns.countplot(x = 'days_left', data = data)
plt.xlabel('days_left')
plt.ylabel('price')
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+1), va='bottom', color= 'black')

# %%
#Scatter plot
plt.title("Price vs arrival_time")
plt.xlabel("arrival_time")
plt.ylabel("Price")
sns.scatterplot(x='arrival_time', y='price', data=data)
# Out:
# <AxesSubplot:title={'center':'Price vs arrival_time'}, xlabel='arrival_time', ylabel='Price'>

# %%
plt.figure(figsize = (10, 5))
plt.title('Price vs arrival_time')
ax=sns.countplot(x = 'arrival_time', data = data)
plt.xlabel('arrival_time')
plt.ylabel('price')
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+1), va='bottom', color= 'black')
    #price is low if it is Late Night or Early Morning Arrival time and High in Night,Evening

# %%
#Scatter plot
plt.title("Price vs departure_time")
plt.xlabel("departure_time")
plt.ylabel("Price")
sns.scatterplot(x='departure_time', y='price', data=data)
# Out:
# <AxesSubplot:title={'center':'Price vs departure_time'}, xlabel='departure_time', ylabel='Price'>

# %%
plt.figure(figsize = (10, 5))
plt.title('Price vs departure_time')
ax=sns.countplot(x = 'departure_time', data = data)
plt.xlabel('departure_time')
plt.ylabel('price')
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+1), va='bottom', color= 'black')
    #price is low if it is Late Night or Early Morning Arrival time and High in Morning, Early Morning and Evening

# %%
#Scatter plot
plt.title("Price vs destination_city")
plt.xlabel("destination_city")
plt.ylabel("Price")
sns.scatterplot(x='destination_city', y='price', data=data)
# Out:
# <AxesSubplot:title={'center':'Price vs destination_city'}, xlabel='destination_city', ylabel='Price'>

# %%
plt.figure(figsize = (10, 5))
plt.title('Price vs destination_city')
ax=sns.countplot(x = 'destination_city', data = data)
plt.xlabel('destination_city')
plt.ylabel('price')
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+1), va='bottom', color= 'black')
#price is high for Destination Mumbai and Delhi, It is low for Hyderabad and Chennai

# %%
#Scatter plot
plt.title("Price vs source_city")
plt.xlabel("source_city")
plt.ylabel("Price")
sns.scatterplot(x='source_city', y='price', data=data)
# Out:
# <AxesSubplot:title={'center':'Price vs source_city'}, xlabel='source_city', ylabel='Price'>

# %%
plt.figure(figsize = (10, 5))
plt.title('Price vs source_city')
ax=sns.countplot(x = 'source_city', data = data)
plt.xlabel('source_city')
plt.ylabel('price')
for p in ax.patches:
    ax.annotate(int(p.get_height()), (p.get_x()+0.25, p.get_height()+1), va='bottom', color= 'black')
    #price is high for Source city is Mumbai/Delhi, It is low for Hyderabad/Chennai

# %%
data["flight"].unique()
# Out:
# array(['SG-8709', 'SG-8157', 'I5-764', ..., '6E-7127', '6E-7259',
#        'AI-433'], dtype=object)

# %%
sns.pairplot(data)

# %%
sns.displot(data=data, x="price")

# %%
sns.displot(data=data, x="duration")

# %%
data['stops'].value_counts()
# Out:
# one            250863
# zero            36004
# two_or_more     13286
# Name: stops, dtype: int64

# %%
data['duration'].value_counts()
# Out:
# 2.17     4242
# 2.25     4036
# 2.75     2879
# 2.08     2755
# 2.83     2323
#          ...
# 37.17       1
# 38.75       1
# 38.50       1
# 36.25       1
# 41.50       1
# Name: duration, Length: 476, dtype: int64

# %%
data['days_left'].value_counts()
# Out:
# 25    6633
# 18    6602
# 39    6593
# 32    6585
# 26    6573
# 24    6542
# 19    6537
# 31    6534
# 33    6532
# 40    6531
# 41    6525
# 28    6522
# 38    6512
# 20    6502
# 30    6501
# 42    6497
# 22    6494
# 36    6490
# 21    6479
# 37    6476
# 43    6472
# 44    6436
# 17    6419
# 11    6417
# 34    6412
# 13    6404
# 23    6401
# 29    6397
# 12    6381
# 27    6360
# 14    6349
# 15    6340
# 45    6314
# 35    6291
# 16    6272
# 46    6160
# 49    6154
# 48    6078
# 47    6069
# 10    5822
# 8     5767
# 6     5740
# 7     5703
# 9     5665
# 5     5392
# 4     5077
# 3     4248
# 2     4026
# 1     1927
# Name: days_left, dtype: int64

# %%
plt.boxplot(data["price"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dfa0af5280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dfa0af58e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dfa0ae8f70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dfa0af5dc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dfa0b030d0>],
#  'means': []}

# %%
plt.boxplot(data["duration"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dfae92c400>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dfae92c9a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dfae92c250>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dfae92cf40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dfae934250>],
#  'means': []}

# %%
plt.boxplot(data["days_left"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dfae97de20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dfae98d430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dfae96e9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1dfae98d9d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1dfae98dca0>],
#  'means': []}

# %%
def detect_outliers_iqr(data1):
    outliers = []
    data1 = sorted(data1)
    q1 = np.percentile(data1, 25)
    q3 = np.percentile(data1, 75)
    # print(q1, q3)
    IQR = q3-q1
    lwr_bound = q1-(1.5*IQR)
    upr_bound = q3+(1.5*IQR)
    # print(lwr_bound, upr_bound)
    for i in data1: 
        if (i<lwr_bound or i>upr_bound):
            outliers.append(i)
    return outliers# Driver code

# %%
price_outliers = detect_outliers_iqr(data['price'])
print("price Outliers from IQR method: ", price_outliers)
# Out:
# price Outliers from IQR method:  [99129, 99204, 99204, 99327, 99327, 99389, 99403, 99403, 99451, 99551, 99577, 99584, 99584, 99677, 99680, 100111, 100204, 100276, 100276, 100288, 100288, 100395, 100473, 100473, 100539, 100671, 100909, 101152, 101152, 101369, 101376, 101531, 101531, 101612, 101780, 101780, 101780, 101824, 101844, 101844, 101844, 101920, 102114, 102114, 102114, 102114, 102114, 102114, 102114, 102114, 102384, 102384, 102404, 102404, 102404, 102648, 102648, 102648, 102648, 102648, 102648, 102648, 102832, 103056, 103335, 103683, 103819, 104031, 104255, 104255, 104255, 104466, 104466, 104624, 104987, 105168, 105185, 105549, 105549, 105638, 105638, 105638, 105744, 105744, 105764, 105764, 105764, 105764, 105961, 106416, 106476, 106753, 106753, 107216, 107216, 107492, 107576, 107597, 107597, 107934, 108360, 108604, 109217, 109776, 110218, 110225, 110850, 110872, 110936, 111163, 111437, 111883, 111964, 111964, 114434, 114507, 114523, 114704, 114705, 115211, 116562, 117307, 123
# ...

# %%
price_outliers = detect_outliers_iqr(data['duration'])
print("duration Outliers from IQR method: ", price_outliers)
# Out:
# duration Outliers from IQR method:  [30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.25, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30.33, 30
# ...

# %%
price_outliers = detect_outliers_iqr(data['days_left'])
print("daysleft Outliers from IQR method: ", price_outliers)
# Out:
# daysleft Outliers from IQR method:  []

# %%
data["price"] = np.where(data["price"] >=123071, 7425,data['price'])

data["duration"] = np.where(data["duration"] >=49.83, 11.25,data['duration'])

# %%
#Scatter plot
plt.title("Price vs duration")
plt.xlabel("duration")
plt.ylabel("Price")
sns.scatterplot(x='duration', y='price', data=data)
# Out:
# <AxesSubplot:title={'center':'Price vs duration'}, xlabel='duration', ylabel='Price'>

# %%
#Scatter plot
plt.title("Price vs days_left")
plt.xlabel("days_left")
plt.ylabel("Price")
sns.scatterplot(x='days_left', y='price', data=data)
# Out:
# <AxesSubplot:title={'center':'Price vs days_left'}, xlabel='days_left', ylabel='Price'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
correlations = data.corr()
sns.heatmap(correlations, annot=True)
# Out:
# <AxesSubplot:>

# %%
correlations.to_csv("corr1.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'airline', 'flight', 'source_city', 'departure_time',
#        'stops', 'arrival_time', 'destination_city', 'class', 'duration',
#        'days_left', 'price'],
#       dtype='object')

# %%
 from sklearn import preprocessing
 le = preprocessing.LabelEncoder()

# %%
data1=data.apply(le.fit_transform)

# %%
data1.head()
# Out:
#    Unnamed: 0  airline  flight  source_city  departure_time  stops  \
# 0           0        4    1408            2               2      2
# 1           1        4    1387            2               1      2
# 2           2        0    1213            2               1      2
# 3           3        5    1559            2               4      2
# 4           4        5    1549            2               4      2
#
#    arrival_time  destination_city  class  duration  days_left  price
# 0             5                 5      1        16          0   2289
# 1             4                 5      1        18          0   2289
# 2             1                 5      1        16          0   2292
# 3             0                 5      1        17          0   2291
# 4             4                 5      1        18          0   2291

# %%
# Import the module train_test_split
from sklearn.model_selection import train_test_split
X = data1.drop(columns=['price','Unnamed: 0','class'],axis=1)
y = data1['price']
# Create four groups using train_test_split. By default, 70% of data is assigned to train, the other 30% to test.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=2)

# %%
X_test.shape
# Out:
# (90046, 9)

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 210107 entries, 127138 to 100879
# Series name: price
# Non-Null Count   Dtype
# --------------   -----
# 210107 non-null  int64
# dtypes: int64(1)
# memory usage: 3.2 MB

# %%
from sklearn.linear_model import LinearRegression
# Initialize a linear regression model object
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lm.predict(X_train)

# %%
y_pred
# Out:
# array([3083.53588309, 3969.3577222 , 4551.52581113, ..., 5044.73801854,
#        8809.15207004, 5452.2751582 ])

# %%
# Evaluate model
#calculate R2 value
from sklearn.metrics import r2_score

r2_base=r2_score(y_train,y_pred)
print(round(r2_base*100,2),'%')

#calculate adj R2 value
Adj_r2_base = 1-(1-r2_base)*(15129/(15129-9-1))
print(round(Adj_r2_base*100,2),'%')
# Out:
# 19.48 %
# 19.43 %

# %%
#Calculate root-mean-square error (RMSE)
from sklearn.metrics import mean_squared_error

lin_mse_base = mean_squared_error(y_pred, y_train)
print('Linear Regression MSE: %.4f' %lin_mse_base )

lin_rmse_base = np.sqrt(lin_mse_base)
print('Linear Regression RMSE: %.4f' %lin_rmse_base )

from sklearn.metrics import mean_absolute_error
lin_mae_base = mean_absolute_error(y_pred, y_train)
print('Linear Regression MAE: %.4f' %lin_mae_base )
# Out:
# Linear Regression MSE: 13580275.4499
# Linear Regression RMSE: 3685.1425
# Linear Regression MAE: 3206.0141

# %%
#Predictions from our Model
#Let's grab predictions off our test set and see how well it did!
y_pred_t=lm.predict(X_test)

# %%
# Evaluate model
#calculate R2 value
from sklearn.metrics import r2_score

r2_base=r2_score(y_test,y_pred_t)
print(round(r2_base*100,2),'%')

#calculate adj R2 value
Adj_r2_base = 1-(1-r2_base)*(600/(600-60-1))
print(round(Adj_r2_base*100,2),'%')
# Out:
# 19.57 %
# 10.47 %

# %%
# model summary
import statsmodels.api as sm
X2=sm.add_constant(X_test)
est=sm.OLS(y_test,X2)
est2=est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     2435.
# Date:                Sat, 13 May 2023   Prob (F-statistic):               0.00
# Time:                        14:46:47   Log-Likelihood:            -8.6722e+05
# No. Observations:               90046   AIC:                         1.734e+06
# Df Residuals:                   90036   BIC:                         1.735e+06
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             2730.3331     60.753     44.942      0.000    2611.258    2849.408
# ...

# %%
import pylab 
import scipy.stats as stats

#residual/error

lm.fit(X_train,y_train)
y_pred_t=lm.predict(X_test)

resid=y_pred_t-y_test

stats.probplot(resid, dist="norm", plot=pylab)
# Out:
# ((array([-4.3229546 , -4.12316835, -4.01446645, ...,  4.01446645,
#           4.12316835,  4.3229546 ]),
#   array([-9466.10841922, -9413.13103035, -9345.43949223, ...,
#           7961.64412158,  7965.57036136,  8097.02719782])),
#  (3555.634549103819, 1.6069530246833965, 0.9648784963070837))

# %%
import seaborn 
import matplotlib.pyplot as plt

#resid=pd.Series(resid)
plt.scatter(y_pred_t,resid)
plt.hlines(0,0,12000)

# %%
plt.hist(resid, bins='auto', color='green', alpha=0.7,rwidth=0.85)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title(' Histogram')
# Out:
# Text(0.5, 1.0, ' Histogram')

# %%
plt.style.use('fivethirtyeight') 
## plotting residual errors in training data 
plt.scatter(lm.predict(X_train), lm.predict(X_train) - y_train, 
 			color = "green", s = 10, label = 'Train data')

# %%
plt.scatter(lm.predict(X_test), lm.predict(X_test) - y_test, 
 			color = "blue", s = 10, label = 'Test data')

# %%
plt.style.use('fivethirtyeight') 

## plotting residual errors in training data 
plt.scatter(lm.predict(X_train), lm.predict(X_train) - y_train, 
 			color = "green", s = 10, label = 'Train data') 

## plotting residual errors in test data 
plt.scatter(lm.predict(X_test), lm.predict(X_test) - y_test, 
 			color = "blue", s = 10, label = 'Test data') 

## plotting line for zero residual error 
plt.hlines(y = 0, xmin = 0, xmax = 5000, linewidth = 2, color='orange')

## plotting legend 
plt.legend(loc = 'upper right') 

## plot title 
plt.title("Residual errors") 

## function to show plot 
plt.savefig("image1.png")
plt.show()

# %%
plt.scatter(resid.index, resid.values)
plt.hlines(0,0,1000)

from statsmodels.stats.stattools import durbin_watson
print(durbin_watson(resid))
# Out:
# 1.9999691383668543

# %%
from sklearn.metrics import r2_score
#VIF = 1/1-r2
VIF = 1/ (1-r2_score(y_test,y_pred_t))
print(VIF)
# Out:
# 1.2432869661477033

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
X = data.drop(columns=['price','Unnamed: 0', 'airline', 'flight', 'source_city', 'departure_time',
      'stops', 'arrival_time', 'destination_city', 'class'],axis=1)
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#      feature       VIF
# 0   duration  2.325846
# 1  days_left  2.325846

# %%
import math

#AIC= 2k - 2ln(sse) (k= # of variables)
sse = sum(resid**2)
AIC_base= abs(2*60 - 2*(math.log(sse)))
print(round(AIC_base,2))

#BIC = n*ln(sse/n) + k*ln(n) (k= # of variables,n = # of observations)
sse = sum(resid**2)
BIC_base = 600*math.log(sse/600)+60*math.log(600)
print(round(BIC_base,2))
# Out:
# 64.34
# 13244.9

# %%
from scipy.stats import skew, kurtosis

#skewness = 0 : Normally distributed
#skewness > 0 : Positively Skewed
#skewness < 0 : Negatively Skewed

#If skewness is less than -1 or greater than 1, the distribution is highly skewed
#If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed
#If skewness is between -0.5 and 0.5, the distribution is approximately symmetric

#skewness
print("\nSkewness:\n", X.skew())

#kurtosis
#General guideline is that if the number is greater than +1, the distribution is too peaked. 
#Likewise, a kurtosis of less than –1 indicates a distribution that is too flat

#kurtosis

print("\nKurtosis:\n", X.kurtosis())
# Out:
# Skewness:
#  duration     0.602218
# days_left   -0.035464
# dtype: float64
#
# Kurtosis:
#  duration    -0.272900
# days_left   -1.156215
# dtype: float64

# %%
data['price'] = np.sqrt(data['price'])
data['days_left'] = np.square(data['days_left'])

# %%
sns.displot(data=data,x=data['price'])

# %%
 from sklearn import preprocessing
 le = preprocessing.LabelEncoder()
data1=data.apply(le.fit_transform)

# %%
X = data1.drop(columns=['price','Unnamed: 0'],axis=1)

y = data1['price']

# Create four groups using train_test_split. By default, 70% of data is assigned to train, the other 30% to test.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=2)

# %%
lm = LinearRegression()

lm.fit(X_train,y_train)
y_pred_t=lm.predict(X_test)

# %%
# model summary
import statsmodels.api as sm
X2=sm.add_constant(X_test)
est=sm.OLS(y_test,X2)
est2=est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.865
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                 5.757e+04
# Date:                Sat, 13 May 2023   Prob (F-statistic):               0.00
# Time:                        14:50:42   Log-Likelihood:            -7.8695e+05
# No. Observations:               90046   AIC:                         1.574e+06
# Df Residuals:                   90035   BIC:                         1.574e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             1.057e+04     27.543    383.715      0.000    1.05e+04    1.06e+04
# ...
